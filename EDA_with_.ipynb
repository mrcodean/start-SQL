# %% [markdown]
# <a href="https://colab.research.google.com/github/mrcodean/start-SQL/blob/main/EDA_with_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA CLEANNING WITH NSSO DATASET (RAJASTHAN STATE)

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns 

from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/MyDrive/INTERNSHIP/GIRP 23/NSSO68_data.csv')
df
# Out:
# <ipython-input-10-d14c1d474cd4>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/gdrive/MyDrive/INTERNSHIP/GIRP 23/NSSO68_data.csv')
#         Unnamed: 0                                 grp  Round_Centre  \
# 0                1  40999999999999992652495293775872.0             1
# 1                2  40999999999999992652495293775872.0             1
# 2                3  40999999999999992652495293775872.0             1
# 3                4  40999999999999992652495293775872.0             1
# 4                5  40999999999999992652495293775872.0             1
# ...            ...                                 ...           ...
# 101657      101658  79999999999999997087170359721984.0             1
# 101658      101659  79999999999999997087170359721984.0             1
# 101659      101660  79999999999999997087170359721984.0             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101662 entries, 0 to 101661
# Columns: 384 entries, Unnamed: 0 to fv_tot
# dtypes: float64(306), int64(76), object(2)
# memory usage: 297.8+ MB

# %%
dfrj = df[df['state_1']== 'RJ']

dfrj
# Out:
#        Unnamed: 0                                 grp  Round_Centre  \
# 32036       32037  47499999999999994892807680557056.0             1
# 32037       32038  47499999999999994892807680557056.0             1
# 32038       32039  47499999999999994892807680557056.0             1
# 32039       32040  47499999999999994892807680557056.0             1
# 32040       32041  47499999999999994892807680557056.0             1
# ...           ...                                 ...           ...
# 93017       93018  77699999999999997125878215606272.0             1
# 93018       93019  77699999999999997125878215606272.0             1
# 93019       93020  77699999999999997125878215606272.0             1
# 93020       93021  77699999999999997125878215606272.0             1
# 93021       93022  77699999999999997125878215606272.0             1
#
#        FSU_number  Round  Schedule_Number  Sample  Sector  state  \
# 32036       47471     68               10       1       2      8
# ...

# %%
dfrj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4128 entries, 32036 to 93021
# Columns: 384 entries, Unnamed: 0 to fv_tot
# dtypes: float64(306), int64(76), object(2)
# memory usage: 12.1+ MB

# %%
dfrj.isnull().sum()
# Out:
# Unnamed: 0        0
# grp               0
# Round_Centre      0
# FSU_number        0
# Round             0
#                  ..
# foodtotal_q       0
# state_1           0
# Region            0
# fruits_df_tt_v    0
# fv_tot            0
# Length: 384, dtype: int64

# %%
dfrj.dtypes
# Out:
# Unnamed: 0          int64
# grp                object
# Round_Centre        int64
# FSU_number          int64
# Round               int64
#                    ...
# foodtotal_q       float64
# state_1            object
# Region              int64
# fruits_df_tt_v    float64
# fv_tot            float64
# Length: 384, dtype: object
